# %% [markdown]
# # What is data?
#
# Probably if you ask this question to three different people, you'll get five different answers! Rather than trying to come up with a definition, let's just look at some examples.
#
# ## Yesterday I ate tomatoes
#
# Suppose I decide to keep a diary about the food I eat. This could be pretty informal:
#
# ```
# Monday
# ------
# bfast: toast and jam
# lunch: tomato soup and roll
# supper: baked beans, sushi, treacle tart
#
# Tuesday
# -------
# bfast: porridge with soya milk
# lunch: tomato soup and roll
# supper: peri-peri chicken, chips, coke
#
# ```
#
# But it's still good enough as a record of my diet. (Not enough greens?)
#
# ## I run
#
# Here's a slightly different kind of diary, recording my running exploits in the first half of December:
#
# ```
# 5/12/15 4.5km
# 7/12/15 3.1km
# 12/12/15 8.6km
#
# ```
#
# ## Just numbers
#
# What about this?
#
# ```
# 23.87
# 19.85
# 19.22
# 28.93
# 29.41
# 22.23
# 23.50
# 24.95
# ```
#
# It's just a list of numbers, right? Apart from the fact that the numbers are in a narrow range, it's pretty much impossible to guess what this information is about.
#
# Here are the same numbers, but with more information added:
#
# ```
# Year   Days of rainfall
# -----------------------
# 2004        23.87
# 2005        19.85
# 2006        19.22
# 2007        28.93
# 2008        29.41
# 2009        22.23
# 2010        23.50
# 2011        24.95
# ```
#
# So now we see that we have got a *time series*: a sequence of data points measured at different times &mdash; in this case, in successive years. The two columns have been given labels which tell us what the time points are, and what kind of quantity has been measured. We could also specify not just *when* but *where* the measurements were taken, namely in Edinburgh.
#
# The bits of information which tell us things like dates, location, the kind of quantity etc is sometimes called *metadata*: it's data about data.
#
# ### Your turn
#
# * Find another example of time series data. Find or make-up some data points that are part of the series.
#
# * Find another example of simple numerical data which is *not* time series data. What metadata would you need to add to make sure that someone else understands the data?
#
# ## Turning Tables
#
# We often represent data in the form of rows and columns. That's what we mean when we talk about a data table (or tabular data). So the rainfall data above had two columns and eight rows, plus a header row.
#
# ### Your turn
#
# * Write down the food diary example so that it looks like a table.
#
# Public bodies collect *lots* of data about all manners of things. More and more, they have been making this available as [open data](https://en.wikipedia.org/wiki/Open_data ) to anyone that wants to use it. Most of the time, the data is provided as some kind of table that we can download over the internet. Here's an example of data about Scottish schools which we've already downloaded for you. We're doing a bit of extra magic to make it easy to display the data, but you can ignore this for the time being.

# %%
import pandas as pd # This is an import statement.
gov_csv = pd.read_csv("../../data/opendatascotland/tutorial_1/schools.csv")
# Display the tabular data 
gov_csv
# Out:
#                                                school  \
# 0   http://data.opendatascotland.org/id/educationa...
# 1   http://data.opendatascotland.org/id/educationa...
# 2   http://data.opendatascotland.org/id/educationa...
# 3   http://data.opendatascotland.org/id/educationa...
# 4   http://data.opendatascotland.org/id/educationa...
# 5   http://data.opendatascotland.org/id/educationa...
# 6   http://data.opendatascotland.org/id/educationa...
# 7   http://data.opendatascotland.org/id/educationa...
# 8   http://data.opendatascotland.org/id/educationa...
# 9   http://data.opendatascotland.org/id/educationa...
# 10  http://data.opendatascotland.org/id/educationa...
# 11  http://data.opendatascotland.org/id/educationa...
# 12  http://data.opendatascotland.org/id/educationa...
# 13  http://data.opendatascotland.org/id/educationa...
# 14  http://data.opendatascotland.org/id/educationa...
# 15  http://data.opendatascotland.org/id/educationa...
# 16  http://data.opendatascotland.org/id/educationa...
# 17  http://data.opendatascotland.org/id/educationa...
# 18  http://data.opendatascotland.org/id/educationa...
# 19  http://data.opendatascotland.org/id/educationa...
# 20  http://data.opendatascotland.org/id/educationa...
# 21  http://data.opendatascotland.org/id/educationa...
# 22  http://data.opendatascotland.org/id/educationa...
# 23  http://data.opendatascotland.org/id/educationa...
# 24  http://data.opendatascotland.org/id/educationa...
# 25  http://data.opendatascotland.org/id/educationa...
# 26  http://data.opendatascotland.org/id/educationa...
# 27  http://data.opendatascotland.org/id/educationa...
# 28  http://data.opendatascotland.org/id/educationa...
# 29  http://data.opendatascotland.org/id/educationa...
# ..                                                ...
# 54  http://data.opendatascotland.org/id/educationa...
# 55  http://data.opendatascotland.org/id/educationa...
# 56  http://data.opendatascotland.org/id/educationa...
# 57  http://data.opendatascotland.org/id/educationa...
# 58  http://data.opendatascotland.org/id/educationa...
# 59  http://data.opendatascotland.org/id/educationa...
# 60  http://data.opendatascotland.org/id/educationa...
# 61  http://data.opendatascotland.org/id/educationa...
# 62  http://data.opendatascotland.org/id/educationa...
# 63  http://data.opendatascotland.org/id/educationa...
# 64  http://data.opendatascotland.org/id/educationa...
# 65  http://data.opendatascotland.org/id/educationa...
# 66  http://data.opendatascotland.org/id/educationa...
# 67  http://data.opendatascotland.org/id/educationa...
# 68  http://data.opendatascotland.org/id/educationa...
# 69  http://data.opendatascotland.org/id/educationa...
# 70  http://data.opendatascotland.org/id/educationa...
# 71  http://data.opendatascotland.org/id/educationa...
# 72  http://data.opendatascotland.org/id/educationa...
# 73  http://data.opendatascotland.org/id/educationa...
# 74  http://data.opendatascotland.org/id/educationa...
# 75  http://data.opendatascotland.org/id/educationa...
# 76  http://data.opendatascotland.org/id/educationa...
# 77  http://data.opendatascotland.org/id/educationa...
# 78  http://data.opendatascotland.org/id/educationa...
# 79  http://data.opendatascotland.org/id/educationa...
# 80  http://data.opendatascotland.org/id/educationa...
# 81  http://data.opendatascotland.org/id/educationa...
# 82  http://data.opendatascotland.org/id/educationa...
# 83  http://data.opendatascotland.org/id/educationa...
#
#                       school_label  latitude  longitude  pupils
# 0               Linlithgow Academy  55.97160   -3.61259    1231
# 1           St Kentigern's Academy  55.87101   -3.63367    1215
# 2             James Young High,The  55.88093   -3.51523    1135
# 3            St Margaret's Academy  55.88937   -3.52213    1094
# 4       Inveralmond Community High  55.90146   -3.51932    1090
# 5                 West Calder High  55.86291   -3.54044     950
# 6             Deans Community High  55.90581   -3.54977     941
# 7                 Broxburn Academy  55.93694   -3.48778     903
# 8                 Bathgate Academy  55.89838   -3.61313     899
# 9                 Whitburn Academy  55.86804   -3.67964     822
# 10                Armadale Academy  55.89481   -3.71436     780
# 11                        Armadale  55.89717   -3.70321     440
# 12                       Balbardie  55.90518   -3.63735     423
# 13                      Linlithgow  55.97165   -3.60945     417
# 14                            Peel  55.89497   -3.53573     407
# 15                     Williamston  55.87527   -3.50414     404
# 16                      Carmondean  55.90662   -3.54190     402
# 17             St Mary's, Bathgate  55.90016   -3.64731     401
# 18                      Harrysmuir  55.90146   -3.51932     401
# 19                 St John Ogilvie  55.90437   -3.55298     368
# 20                     St Nicholas  55.93284   -3.48396     364
# 21                     St Nicholas  55.93461   -3.47285     364
# 22                        Broxburn  55.93545   -3.47440     361
# 23                      Windyknowe  55.89849   -3.66481     359
# 24                        Parkhead  55.85232   -3.56651     354
# 25                Whitdale Primary  55.86560   -3.67475     345
# 26                 Simpson Primary  55.89066   -3.62362     336
# 27                         Bankton  55.88157   -3.50703     331
# 28                      Eastertoun  55.89812   -3.71076     329
# 29              Howden St Andrew's  55.89300   -3.50936     322
# ..                             ...       ...        ...     ...
# 54             St John The Baptist  55.83026   -3.70456     176
# 55                       Polkemmet  55.86204   -3.69082     169
# 56                      Falla Hill  55.82792   -3.71016     168
# 57  Pumpherston and Uphall Station  55.90655   -3.49183     168
# 58  Pumpherston and Uphall Station  55.90885   -3.49211     168
# 59             Our Lady of Lourdes  55.87509   -3.62618     148
# 60                      Blackridge  55.88429   -3.77368     143
# 61                    St Columba's  55.90156   -3.60997     126
# 62         St Joseph's, Linlithgow  55.97165   -3.60945     124
# 63                       St Paul's  55.89645   -3.45757     117
# 64              St Mary's, Polbeth  55.85996   -3.55515     115
# 65                        Pinewood  55.87249   -3.61281     115
# 66                        Seafield  55.87864   -3.58856     115
# 67                      Winchburgh  55.95631   -3.46832     102
# 68                      Stoneyburn  55.84932   -3.62739      96
# 69                       Addiewell  55.84520   -3.61746      95
# 70                       Longridge  55.84493   -3.67811      92
# 71                        Bridgend  55.96256   -3.53472      78
# 72                       Cedarbank  55.89696   -3.51670      75
# 73                      Torphichen  55.93437   -3.65513      71
# 74                     Holy Family  55.95631   -3.46832      60
# 75                       Blackburn  55.87750   -3.63012      59
# 76           Ogilvie School Campus  55.90653   -3.52634      56
# 77              Our Lady's Primary  55.84601   -3.63337      53
# 78                       Westfield  55.92798   -3.70243      38
# 79                      St Thomas'  55.84520   -3.61746      36
# 80                  Beatlie School  55.89686   -3.49517      34
# 81                        Woodmuir  55.82852   -3.65678      27
# 82                       Burnhouse  55.86204   -3.69082      16
# 83                        Dechmont  55.91956   -3.54255      14
#
# [84 rows x 5 columns]
